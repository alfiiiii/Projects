# %% [markdown]
# **PREPROCESSING DATA**
# ___________________________________________________________________________

# %%
import pandas as pd
df = pd.read_csv("Kemiskinan_JawaTengah.csv")
df
# Out:
#             Kabupaten/Kota  Garis Kemiskinan (Rp/kapita/bln) 2020  \
# 0        Kabupaten Cilacap                               351735.0
# 1       Kabupaten Banyumas                               406250.0
# 2    Kabupaten Purbalingga                               375199.0
# 3   Kabupaten Banjarnegara                               318334.0
# 4        Kabupaten Kebumen                               380557.0
# 5      Kabupaten Purworejo                               364289.0
# 6       Kabupaten Wonosobo                               362683.0
# 7       Kabupaten Magelang                               342430.0
# 8       Kabupaten Boyolali                               347520.0
# 9         Kabupaten Klaten                               419510.0
# 10     Kabupaten Sukoharjo                               393776.0
# 11      Kabupaten Wonogiri                               341643.0
# 12   Kabupaten Karanganyar                               385563.0
# ...

# %%
# Memeriksa missing value
for i in df.columns:
    miss = df[i].isnull().sum()
    if miss>0:
        print('\033[1m', '\33[31m')
        print("{} terdapat {} missing value(s)".format(i,miss))
    else:
        print('\033[1m', '\33[34m')
        print("{} tidak terdapat missing value!".format(i))
# Out:
#
# Kabupaten/Kota tidak terdapat missing value!
#
# Garis Kemiskinan (Rp/kapita/bln) 2020 tidak terdapat missing value!
#
# Garis Kemiskinan (Rp/kapita/bln) 2021 tidak terdapat missing value!
#
# Garis Kemiskinan (Rp/kapita/bln) 2022 tidak terdapat missing value!
#
# Jumlah Penduduk Miskin (ribu jiwa) 2020 tidak terdapat missing value!
#
# Jumlah Penduduk Miskin (ribu jiwa) 2021 tidak terdapat missing value!
#
# Jumlah Penduduk Miskin (ribu jiwa) 2022 tidak terdapat missing value!
#
# Persentase Penduduk Miskin (persen) 2020 tidak terdapat missing value!
#
# Persentase Penduduk Miskin (persen) 2021 tidak terdapat missing value!
#
# Persentase Penduduk Miskin (persen) 2022 tidak terdapat missing value!

# %%
import pandas as pd

# Membaca data dari file CSV
df = pd.read_csv('Kemiskinan_JawaTengah.csv')

# Memeriksa missing value
for column in df.columns:
    missing_values = df[column].isnull().sum()
    if missing_values > 0:
        print('\033[1m', '\33[31m')
        print("{} terdapat {} missing value(s)".format(column, missing_values))
    else:
        print('\033[1m', '\33[34m')
        print("{} tidak terdapat missing value!".format(column))

# Memeriksa data redundan
duplicates = df.duplicated()
if duplicates.any():
    duplicate_rows = df[duplicates]
    print('\033[1m', '\33[31m')
    print("Data memiliki {} baris redundan:".format(len(duplicate_rows)))
    print(duplicate_rows)
else:
    print('\033[1m', '\33[32m')
    print("Data tidak memiliki baris redundan!")
# Out:
#
# Kabupaten/Kota tidak terdapat missing value!
#
# Garis Kemiskinan (Rp/kapita/bln) 2020 tidak terdapat missing value!
#
# Garis Kemiskinan (Rp/kapita/bln) 2021 tidak terdapat missing value!
#
# Garis Kemiskinan (Rp/kapita/bln) 2022 tidak terdapat missing value!
#
# Jumlah Penduduk Miskin (ribu jiwa) 2020 tidak terdapat missing value!
#
# Jumlah Penduduk Miskin (ribu jiwa) 2021 tidak terdapat missing value!
#
# Jumlah Penduduk Miskin (ribu jiwa) 2022 tidak terdapat missing value!
#
# Persentase Penduduk Miskin (persen) 2020 tidak terdapat missing value!
#
# Persentase Penduduk Miskin (persen) 2021 tidak terdapat missing value!
#
# Persentase Penduduk Miskin (persen) 2022 tidak terdapat missing value!
#
# Data tidak memiliki baris redundan!

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Normalisasi data menggunakan StandardScaler
scaler = StandardScaler()
numerical_columns = ["Garis Kemiskinan (Rp/kapita/bln) 2020", "Garis Kemiskinan (Rp/kapita/bln) 2021", "Garis Kemiskinan (Rp/kapita/bln) 2022",
                     "Jumlah Penduduk Miskin (ribu jiwa) 2020", "Jumlah Penduduk Miskin (ribu jiwa) 2021", "Jumlah Penduduk Miskin (ribu jiwa) 2022",
                     "Persentase Penduduk Miskin (persen) 2020", "Persentase Penduduk Miskin (persen) 2021", "Persentase Penduduk Miskin (persen) 2022"]
df_normalized = df.copy()  # Salin dataset asli ke dataset baru
df_normalized[numerical_columns] = scaler.fit_transform(df_normalized[numerical_columns])

# Menyimpan dataset baru setelah normalisasi
df_normalized.to_csv('df_normalized.csv', index=False)
print("Statistik Ringkasan Dataset Setelah Normalisasi:")
df_normalized
# Out:
# Statistik Ringkasan Dataset Setelah Normalisasi:
#             Kabupaten/Kota  Garis Kemiskinan (Rp/kapita/bln) 2020  \
# 0        Kabupaten Cilacap                              -0.897592
# 1       Kabupaten Banyumas                               0.113665
# 2    Kabupaten Purbalingga                              -0.462333
# 3   Kabupaten Banjarnegara                              -1.517183
# 4        Kabupaten Kebumen                              -0.362942
# 5      Kabupaten Purworejo                              -0.664715
# 6       Kabupaten Wonosobo                              -0.694506
# 7       Kabupaten Magelang                              -1.070201
# 8       Kabupaten Boyolali                              -0.975781
# 9         Kabupaten Klaten                               0.359639
# 10     Kabupaten Sukoharjo                              -0.117729
# 11      Kabupaten Wonogiri                              -1.084800
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_normalized = df.copy()
df_normalized[numerical_columns] = scaler.fit_transform(df_normalized[numerical_columns])

print("Dataset Setelah Normalisasi:")
df_normalized
# Out:
# Dataset Setelah Normalisasi:
#             Kabupaten/Kota  Garis Kemiskinan (Rp/kapita/bln) 2020  \
# 0        Kabupaten Cilacap                               0.199228
# 1       Kabupaten Banyumas                               0.454581
# 2    Kabupaten Purbalingga                               0.309135
# 3   Kabupaten Banjarnegara                               0.042775
# 4        Kabupaten Kebumen                               0.334233
# 5      Kabupaten Purworejo                               0.258032
# 6       Kabupaten Wonosobo                               0.250509
# 7       Kabupaten Magelang                               0.155643
# 8       Kabupaten Boyolali                               0.179485
# 9         Kabupaten Klaten                               0.516692
# 10     Kabupaten Sukoharjo                               0.396152
# 11      Kabupaten Wonogiri                               0.151956
# 12   Kabupaten Karanganyar                               0.357681
# ...

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**
# __________________________________________________________________________

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Kemiskinan_JawaTengah.csv")
print('\033[1m', '\33[32m')
print("Tampilan beberapa baris pertama dari dataset:")
df.head()
# Out:
#
# Tampilan beberapa baris pertama dari dataset:
#            Kabupaten/Kota  Garis Kemiskinan (Rp/kapita/bln) 2020  \
# 0       Kabupaten Cilacap                               351735.0
# 1      Kabupaten Banyumas                               406250.0
# 2   Kabupaten Purbalingga                               375199.0
# 3  Kabupaten Banjarnegara                               318334.0
# 4       Kabupaten Kebumen                               380557.0
#
#    Garis Kemiskinan (Rp/kapita/bln) 2021  \
# 0                               363367.0
# 1                               417086.0
# 2                               384183.0
# 3                               328679.0
# 4                               390599.0
#
#    Garis Kemiskinan (Rp/kapita/bln) 2022  \
# 0                               384955.0
# 1                               441520.0
# 2                               407849.0
# 3                               351333.0
# 4                               416004.0
#
# ...

# %%
# Informasi dataset
print('\033[1m', '\33[32m')
print("\nInformasi dataset:")
print('\033[1m', '\33[30m')
df.info()
# Out:
#
#
# Informasi dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 10 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Kabupaten/Kota                            35 non-null     object
#  1   Garis Kemiskinan (Rp/kapita/bln) 2020     35 non-null     float64
#  2   Garis Kemiskinan (Rp/kapita/bln) 2021     35 non-null     float64
#  3   Garis Kemiskinan (Rp/kapita/bln) 2022     35 non-null     float64
#  4   Jumlah Penduduk Miskin (ribu jiwa) 2020   35 non-null     float64
#  5   Jumlah Penduduk Miskin (ribu jiwa) 2021   35 non-null     float64
#  6   Jumlah Penduduk Miskin (ribu jiwa) 2022   35 non-null     float64
#  7   Persentase Penduduk Miskin (persen) 2020  35 non-null     float64
#  8   Persentase Penduduk Miskin (persen) 2021  35 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Garis Kemiskinan (Rp/kapita/bln) 2020  \
# count                              35.000000
# mean                           400122.542857
# std                             54695.171977
# min                            309202.000000
# 25%                            357971.000000
# 50%                            395001.000000
# 75%                            430781.500000
# max                            522691.000000
#
#        Garis Kemiskinan (Rp/kapita/bln) 2021  \
# count                              35.000000
# mean                           414276.457143
# std                             57725.580927
# min                            318330.000000
# 25%                            368561.500000
# 50%                            407387.000000
# 75%                            445514.500000
# max                            543929.000000
#
#        Garis Kemiskinan (Rp/kapita/bln) 2022  \
# count                              35.000000
# mean                           441464.514286
# ...

# %%
# Visualisasi Data
# Histogram
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="Garis Kemiskinan (Rp/kapita/bln) 2020", kde=True, )
plt.title("Distribusi Garis Kemiskinan 2020")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln) 2020")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# > Histogram diatas terdapat Fluktuasi garis kemiskinan atau pendapatan yang dikatakan miskin pada tiap bulannya di tahun 2020

# %%
# Visualisasi Data
# Histogram
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="Garis Kemiskinan (Rp/kapita/bln) 2021", kde=True, color = "green")
plt.title("Distribusi Garis Kemiskinan 2021")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln) 2021")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# > Histogram diatas terdapat Fluktuasi garis kemiskinan atau pendapatan yang dikatakan miskin pada tiap bulannya di tahun 2021

# %%
# Visualisasi Data
# Histogram
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="Garis Kemiskinan (Rp/kapita/bln) 2022", kde=True, color = "orange")
plt.title("Distribusi Garis Kemiskinan 2022")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln) 2022")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# > Histogram diatas terdapat Fluktuasi garis kemiskinan atau pendapatan yang dikatakan miskin pada tiap bulannya di tahun 2022

# %%
# Histogram untuk setiap tahun
numerical_columns = ["Garis Kemiskinan (Rp/kapita/bln) 2020", "Garis Kemiskinan (Rp/kapita/bln) 2021", "Garis Kemiskinan (Rp/kapita/bln) 2022"]
colors = ["blue", "green", "orange"]  # Warna untuk setiap tahun
plt.figure(figsize=(12, 6))
for i, column in enumerate(numerical_columns):
    sns.histplot(data=df, x=column, kde=True, label=column, color=colors[i])
plt.title("Distribusi Garis Kemiskinan")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln)")
plt.ylabel("Frekuensi")
plt.legend()
plt.show()

# %% [markdown]
# > Histogram diatas menunjukkan bahwasannya pada tiap tahun terdapat kenaikan pendapatan penduduk bisa dilihat oleh garis grafik, akan tetapi hal tersebut tidak bisa kita simpulkan apakah tiap tahunnya tersebut penduduk bertambah miskin karena bisa saja pada kenaikan tahun terdapat inflasi sehingga bisa memicu kenaikkan pendapatan penduduk

# %%
# Scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x="Garis Kemiskinan (Rp/kapita/bln) 2020", y="Persentase Penduduk Miskin (persen) 2020")
plt.title("Hubungan antara Garis Kemiskinan dan Persentase Penduduk Miskin")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln) 2020")
plt.ylabel("Persentase Penduduk Miskin (persen) 2020")
plt.show()

# %% [markdown]
# > Terdapat korelasi pada scatter plot tersebut dikarenakan titik-titik yang menyebar. Jadi intinya Garis Kemiskinan dan persentasi penduduk miskin memiliki hubungan satu sama lain yang mana jika dikatakan penduduk itu miskin dikarenakan adanya pendapatan yang hanya mencapai 300.000 hingga 500.000 pada tahun 2020

# %%
# Scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x="Garis Kemiskinan (Rp/kapita/bln) 2021", y="Persentase Penduduk Miskin (persen) 2021", color = "green")
plt.title("Hubungan antara Garis Kemiskinan dan Persentase Penduduk Miskin")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln) 2021")
plt.ylabel("Persentase Penduduk Miskin (persen) 2021")
plt.show()

# %% [markdown]
# > Terdapat korelasi pada scatter plot tersebut dikarenakan titik-titik yang menyebar. Jadi intinya Garis Kemiskinan dan persentasi penduduk miskin memiliki hubungan satu sama lain yang mana jika dikatakan penduduk itu miskin dikarenakan adanya pendapatan yang hanya mencapai 300.000 hingga 550.000 tiap bulannya, pada tahun 2021

# %%
# Scatter plot
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df, x="Garis Kemiskinan (Rp/kapita/bln) 2022", y="Persentase Penduduk Miskin (persen) 2022", color = "orange")
plt.title("Hubungan antara Garis Kemiskinan dan Persentase Penduduk Miskin")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln) 2022")
plt.ylabel("Persentase Penduduk Miskin (persen) 2022")
plt.show()

# %% [markdown]
# > Terdapat korelasi pada scatter plot tersebut dikarenakan titik-titik yang menyebar. Jadi intinya Garis Kemiskinan dan persentasi penduduk miskin memiliki hubungan satu sama lain yang mana jika dikatakan penduduk itu miskin dikarenakan adanya pendapatan yang hanya mencapai 300.000 hingga 550.000 tiap bulannya, pada tahun 2022

# %%
# Scatter plot untuk setiap tahun
plt.figure(figsize=(12, 6))
for column in numerical_columns:
    sns.scatterplot(data=df, x=column, y="Persentase Penduduk Miskin (persen) " + column[-4:], label=column)
plt.title("Hubungan antara Garis Kemiskinan dan Persentase Penduduk Miskin")
plt.xlabel("Garis Kemiskinan (Rp/kapita/bln)")
plt.ylabel("Persentase Penduduk Miskin (persen)")
plt.legend()
plt.show()

# %% [markdown]
# > Persentase Penduduk Miskin dan Garis Kemiskinan pada scatter plot diatas menunjukkan saling berhubungan erat, sebab hal tersebut diberitahukan oleh titik-titik yang menyebar. Dengan melihat bahwa pendapatan Warga Jawa Tengah meningkat itu memengaruhi Persentase Penduduk Miskin

# %%
# Heatmap korelasi
plt.figure(figsize=(10, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Heatmap Korelasi")
plt.show()

# %% [markdown]
# **MODELLING DATA WITH K-MEANS CLUSTERING**
# ___________________________________________________________________________

# %%
from sklearn.cluster import KMeans

# Klasterisasi untuk tahun 2020
X_2020 = df[["Garis Kemiskinan (Rp/kapita/bln) 2020", "Persentase Penduduk Miskin (persen) 2020"]]
kmeans_2020 = KMeans(n_clusters=3, random_state=42)
kmeans_2020.fit(X_2020)
df["Cluster 2020"] = kmeans_2020.labels_

# Klasterisasi untuk tahun 2021
X_2021 = df[["Garis Kemiskinan (Rp/kapita/bln) 2021", "Persentase Penduduk Miskin (persen) 2021"]]
kmeans_2021 = KMeans(n_clusters=3, random_state=42)
kmeans_2021.fit(X_2021)
df["Cluster 2021"] = kmeans_2021.labels_

# Klasterisasi untuk tahun 2022
X_2022 = df[["Garis Kemiskinan (Rp/kapita/bln) 2022", "Persentase Penduduk Miskin (persen) 2022"]]
kmeans_2022 = KMeans(n_clusters=3, random_state=42)
kmeans_2022.fit(X_2022)
df["Cluster 2022"] = kmeans_2022.labels_

# Menampilkan hasil klasterisasi
print("Hasil Klasterisasi:")
df[["Kabupaten/Kota", "Cluster 2020", "Cluster 2021", "Cluster 2022"]]
# Out:
# Hasil Klasterisasi:
#             Kabupaten/Kota  Cluster 2020  Cluster 2021  Cluster 2022
# 0        Kabupaten Cilacap             2             2             1
# 1       Kabupaten Banyumas             0             0             0
# 2    Kabupaten Purbalingga             0             2             1
# 3   Kabupaten Banjarnegara             2             2             1
# 4        Kabupaten Kebumen             0             0             0
# 5      Kabupaten Purworejo             2             2             1
# 6       Kabupaten Wonosobo             2             2             1
# 7       Kabupaten Magelang             2             2             1
# 8       Kabupaten Boyolali             2             2             1
# 9         Kabupaten Klaten             0             0             0
# 10     Kabupaten Sukoharjo             0             0             0
# 11      Kabupaten Wonogiri             2             2             1
# ...

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Clustering for each year
for year in range(2020, 2023):
    # Perform clustering
    kmeans = KMeans(n_clusters=3)
    kmeans.fit(df_normalized[[f"Garis Kemiskinan (Rp/kapita/bln) {year}"]])
    df[f"Cluster {year}"] = kmeans.labels_

# %%
# Clustering for each year
for year in range(2020, 2023):
    # Perform clustering
    kmeans = KMeans(n_clusters=3)
    kmeans.fit(df_normalized[[f"Garis Kemiskinan (Rp/kapita/bln) {year}"]])
    df[f"Cluster {year}"] = kmeans.labels_

    # Visualisasi
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=df, x=f"Garis Kemiskinan (Rp/kapita/bln) {year}", y=f"Persentase Penduduk Miskin (persen) {year}", hue=f"Cluster {year}", palette=["red", "yellow", "green"], hue_order=[0, 1, 2])
    plt.title(f"Hubungan antara Garis Kemiskinan dan Persentase Penduduk Miskin {year}")
    plt.xlabel(f"Garis Kemiskinan (Rp/kapita/bln) {year}")
    plt.ylabel(f"Persentase Penduduk Miskin (persen) {year}")
    plt.show()

# %% [markdown]
# > Pada scatter plot diatas kita bisa menyimpulkan dari tahun 2021-2022 kota yang memasuki Cluster 2 mengalami penurunan pendapatan dan memperbesar peluangnya presentasi penduduk miskin jika diasumsikan keadaan 2023 dan seterusnya bisa saja cluster 2 mengalami penurunan pendapatan yang signifikan dilihat dari pola scatter plot tahun 2020-2022

# %% [markdown]
# **MODEL EVALUATION**
# __________________________________________________________________________

# %%
# Hitung statistik deskriptif untuk setiap klaster pada setiap tahun
for year in range(2020, 2023):
    for cluster in range(3):
        cluster_data = df[df[f"Cluster {year}"] == cluster]
        statistics = cluster_data[[f"Garis Kemiskinan (Rp/kapita/bln) {year}", f"Persentase Penduduk Miskin (persen) {year}"]].describe()
        print(f"Cluster {cluster} - Year {year}:")
        print(statistics)
        print()
# Out:
# Cluster 0 - Year 2020:
#        Garis Kemiskinan (Rp/kapita/bln) 2020  \
# count                              18.000000
# mean                           405077.222222
# std                             19704.628705
# min                            375199.000000
# 25%                            391334.000000
# 50%                            403797.000000
# 75%                            416396.500000
# max                            445913.000000
#
#        Persentase Penduduk Miskin (persen) 2020
# count                                 18.000000
# mean                                  11.431667
# std                                    2.718374
# min                                    7.170000
# 25%                                    9.990000
# 50%                                   11.160000
# 75%                                   13.167500
# max                                   16.020000
#
# Cluster 1 - Year 2020:
#        Garis Kemiskinan (Rp/kapita/bln) 2020  \
# ...

# %%
# uji ANOVA untuk perbandingan persentase penduduk miskin antara ketiga klaster pada tahun 2021
cluster_0 = df[df["Cluster 2022"] == 0]["Persentase Penduduk Miskin (persen) 2022"]
cluster_1 = df[df["Cluster 2022"] == 1]["Persentase Penduduk Miskin (persen) 2022"]
cluster_2 = df[df["Cluster 2022"] == 2]["Persentase Penduduk Miskin (persen) 2022"]
f_statistic, p_value = f_oneway(cluster_0, cluster_1, cluster_2)
print("ANOVA - Year 2022")
print("F-Statistic:", f_statistic)
print("P-Value:", p_value)
print()
# Out:
# ANOVA - Year 2022
# F-Statistic: 7.8439620108826285
# P-Value: 0.001689915474999231

# %% [markdown]
# > Kesimpulan ini menunjukkan bahwa faktor-faktor lain selain pendapatan kemungkinan besar mempengaruhi perbedaan persentase penduduk miskin di klaster-klaster tersebut pada tahun 2021. Walaupun begitu klustering yang sudah dilakukan sebelumnya itu sudah cukup baik

# %%
# Visualisasi perbandingan menggunakan box plot
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x="Cluster 2022", y="Garis Kemiskinan (Rp/kapita/bln) 2022")
plt.title("Perbandingan Pendapatan antara Klaster - Year 2022")
plt.xlabel("Cluster")
plt.ylabel("Garis Kemiskinan (Rp/kapita/bln) 2022")
plt.show()

# %% [markdown]
# > Seperti yang dijelaskan oleh scatter plot, Cluster 2 mengalami penurunan pendapatan di tahun 2022 dan bisa saja seterusnya

# %%
# Evaluating clustering quality
silhouette_scores = []
for year in range(2020, 2023):
    column_name = f"Garis Kemiskinan (Rp/kapita/bln) {year}"
    score = silhouette_score(df_normalized[[column_name]], df[f"Cluster {year}"])
    silhouette_scores.append(score)

plt.figure(figsize=(10, 6))
plt.plot(range(2020, 2023), silhouette_scores, marker='o')
plt.xlabel('Year')
plt.ylabel('Silhouette Score')
plt.title('Evaluating Clustering Quality')
plt.show()

# %% [markdown]
# > Nilai Silhouette Score naik dari tahun ke tahun, itu menunjukkan bahwa pembentukan klaster menjadi lebih baik. Jadi kami melakukan permodellan klastering dengan K-Means memiliki kapasitas untuk membuat sebuah asumsi
#
#
# > Kabupaten/kota di Provinsi Jawa Tengah yang akan mengalami penurunan ialah yang nantinya masuk kedalam Cluster 2 sebab dilihat dari pola scatter plot terdapat sebuah pola penurunan yang berturut-turut tahun 2021-2022 pada Cluster 2
